# %%
import numpy as np

a = np.array ([1,2,3,4])
b = np.array ([10,20,30,40])
b = np.append(b,np.sum(b))
b
# Out:
# array([ 10,  20,  30,  40, 100])

# %%
a = 14507491
b = 606173
c = 8133663
a - b - c
# Out:
# 5767655
