# %%
from matplotlib import pylab
import numpy as np

# %%
x = np.linspace(1,10,25)
y = x*x*2

print(x)
print(y)
# Out:
# [ 1.     1.375  1.75   2.125  2.5    2.875  3.25   3.625  4.     4.375
#   4.75   5.125  5.5    5.875  6.25   6.625  7.     7.375  7.75   8.125
#   8.5    8.875  9.25   9.625 10.   ]
# [  2.        3.78125   6.125     9.03125  12.5      16.53125  21.125
#   26.28125  32.       38.28125  45.125    52.53125  60.5      69.03125
#   78.125    87.78125  98.      108.78125 120.125   132.03125 144.5
#  157.53125 171.125   185.28125 200.     ]
